# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/9q/jm09lzq10jq70lvcx2l0ywfm0000gn/T/pip-req-build-0cuyikz3
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/9q/jm09lzq10jq70lvcx2l0ywfm0000gn/T/pip-req-build-0cuyikz3
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (3.7.2)
# Requirement already satisfied: scipy in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cpu

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301957, train error 89.55,  test loss 2.303112, test error 89.93
# Epoch   100, train loss 1.946004, train error 73.78,  test loss 1.802601, test error 70.80
# Epoch   200, train loss 1.924646, train error 74.07,  test loss 1.749507, test error 70.35
# Epoch   300, train loss 1.907364, train error 71.95,  test loss 1.746325, test error 70.53
# Epoch   400, train loss 1.907264, train error 72.18,  test loss 1.743047, test error 69.82
# Epoch   500, train loss 1.918680, train error 73.38,  test loss 1.740780, test error 70.47
# Epoch   600, train loss 1.902827, train error 71.47,  test loss 1.740160, test error 69.93
# Epoch   700, train loss 1.907832, train error 71.65,  test loss 1.760752, test error 69.88
# Epoch   800, train loss 1.897513, train error 72.22,  test loss 1.735589, test error 69.32
# Epoch   900, train loss 1.893897, train error 70.68,  test loss 1.743465, test error 68.45
# Training model with   4 hidden variables
# Epoch     0, train loss 2.303697, train error 89.72,  test loss 2.302692, test error 89.25
# Epoch   100, train loss 1.837074, train error 68.90,  test loss 1.689732, test error 66.97
# Epoch   200, train loss 1.808737, train error 68.45,  test loss 1.662285, test error 65.07
# Epoch   300, train loss 1.804153, train error 67.55,  test loss 1.652836, test error 64.93
# Epoch   400, train loss 1.786886, train error 67.18,  test loss 1.646145, test error 63.53
# Epoch   500, train loss 1.782198, train error 66.72,  test loss 1.633737, test error 63.22
# Epoch   600, train loss 1.772455, train error 66.95,  test loss 1.631385, test error 62.58
# Epoch   700, train loss 1.779328, train error 67.30,  test loss 1.638684, test error 63.28
# Epoch   800, train loss 1.771814, train error 66.80,  test loss 1.618011, test error 62.35
# Epoch   900, train loss 1.768130, train error 65.68,  test loss 1.618439, test error 63.60
# Training model with   6 hidden variables
# Epoch     0, train loss 2.298775, train error 89.15,  test loss 2.305861, test error 89.78
# Epoch   100, train loss 1.655457, train error 58.50,  test loss 1.463770, test error 57.08
# Epoch   200, train loss 1.611401, train error 57.35,  test loss 1.438487, test error 55.60
# Epoch   300, train loss 1.587985, train error 56.30,  test loss 1.419921, test error 55.17
# Epoch   400, train loss 1.578424, train error 56.28,  test loss 1.418555, test error 54.53
# Epoch   500, train loss 1.570450, train error 56.35,  test loss 1.422726, test error 55.38
# Epoch   600, train loss 1.564987, train error 55.88,  test loss 1.413706, test error 54.85
# Epoch   700, train loss 1.562336, train error 56.20,  test loss 1.427734, test error 55.03
# Epoch   800, train loss 1.567232, train error 55.17,  test loss 1.427211, test error 54.97
# Epoch   900, train loss 1.561760, train error 55.33,  test loss 1.414494, test error 55.65
# Training model with   8 hidden variables
# Epoch     0, train loss 2.206176, train error 82.72,  test loss 2.185854, test error 81.62
# Epoch   100, train loss 1.627686, train error 58.75,  test loss 1.448500, test error 56.33
# Epoch   200, train loss 1.587304, train error 56.78,  test loss 1.437490, test error 56.00
# Epoch   300, train loss 1.568679, train error 55.62,  test loss 1.434501, test error 55.70
# Epoch   400, train loss 1.548829, train error 55.15,  test loss 1.451673, test error 55.50
# Epoch   500, train loss 1.535577, train error 55.08,  test loss 1.439434, test error 55.00
# Epoch   600, train loss 1.529671, train error 54.08,  test loss 1.431176, test error 54.70
# Epoch   700, train loss 1.523361, train error 54.30,  test loss 1.440287, test error 54.58
# Epoch   800, train loss 1.531086, train error 54.70,  test loss 1.451641, test error 55.53
# Epoch   900, train loss 1.518614, train error 54.55,  test loss 1.454134, test error 55.40
# Training model with  10 hidden variables
# Epoch     0, train loss 2.257646, train error 85.95,  test loss 2.254690, test error 86.43
# Epoch   100, train loss 1.601188, train error 55.60,  test loss 1.444044, test error 55.30
# Epoch   200, train loss 1.536004, train error 53.08,  test loss 1.406276, test error 52.67
# Epoch   300, train loss 1.504150, train error 51.62,  test loss 1.382131, test error 51.30
# Epoch   400, train loss 1.488691, train error 51.08,  test loss 1.377848, test error 51.88
# Epoch   500, train loss 1.480295, train error 51.15,  test loss 1.393837, test error 52.65
# Epoch   600, train loss 1.470313, train error 51.20,  test loss 1.396561, test error 53.38
# Epoch   700, train loss 1.459498, train error 50.85,  test loss 1.402216, test error 52.67
# Epoch   800, train loss 1.454597, train error 50.67,  test loss 1.392051, test error 51.70
# Epoch   900, train loss 1.445117, train error 50.92,  test loss 1.407769, test error 52.08
# Training model with  14 hidden variables
# Epoch     0, train loss 2.205396, train error 82.57,  test loss 2.187590, test error 81.70
# Epoch   100, train loss 1.450046, train error 49.47,  test loss 1.373719, test error 50.78
# Epoch   200, train loss 1.360470, train error 46.60,  test loss 1.365471, test error 51.25
# Epoch   300, train loss 1.323848, train error 45.58,  test loss 1.371804, test error 51.17
# Epoch   400, train loss 1.299976, train error 44.62,  test loss 1.366529, test error 50.50
# Epoch   500, train loss 1.287170, train error 44.62,  test loss 1.393110, test error 50.78
# Epoch   600, train loss 1.278577, train error 44.35,  test loss 1.414660, test error 51.40
# Epoch   700, train loss 1.269357, train error 44.10,  test loss 1.421582, test error 51.55
# Epoch   800, train loss 1.268027, train error 44.22,  test loss 1.430618, test error 51.97
# Epoch   900, train loss 1.268318, train error 43.97,  test loss 1.447085, test error 51.72
# Training model with  18 hidden variables
# Epoch     0, train loss 2.147816, train error 79.00,  test loss 2.132241, test error 79.75
# Epoch   100, train loss 1.362661, train error 47.25,  test loss 1.373863, test error 52.03
# Epoch   200, train loss 1.250102, train error 43.17,  test loss 1.397462, test error 51.67
# Epoch   300, train loss 1.214697, train error 41.83,  test loss 1.449081, test error 53.60
# Epoch   400, train loss 1.189813, train error 41.05,  test loss 1.480378, test error 53.58
# Epoch   500, train loss 1.177201, train error 41.17,  test loss 1.507220, test error 54.05
# Epoch   600, train loss 1.189919, train error 41.10,  test loss 1.527035, test error 53.65
# Epoch   700, train loss 1.169552, train error 40.83,  test loss 1.521378, test error 53.33
# Epoch   800, train loss 1.157634, train error 40.08,  test loss 1.553435, test error 54.55
# Epoch   900, train loss 1.147578, train error 39.65,  test loss 1.541972, test error 53.67
# Training model with  22 hidden variables
# Epoch     0, train loss 2.202666, train error 81.50,  test loss 2.172277, test error 80.75
# Epoch   100, train loss 1.275484, train error 43.40,  test loss 1.357039, test error 50.10
# Epoch   200, train loss 1.153005, train error 38.08,  test loss 1.434554, test error 50.58
# Epoch   300, train loss 1.082649, train error 35.72,  test loss 1.496511, test error 51.88
# Epoch   400, train loss 1.051898, train error 35.28,  test loss 1.582869, test error 53.17
# Epoch   500, train loss 1.023383, train error 33.95,  test loss 1.615029, test error 52.53
# Epoch   600, train loss 1.024427, train error 34.47,  test loss 1.675614, test error 53.78
# Epoch   700, train loss 1.006135, train error 34.18,  test loss 1.688052, test error 53.25
# Epoch   800, train loss 1.002191, train error 33.93,  test loss 1.721680, test error 53.50
# Epoch   900, train loss 0.991975, train error 33.72,  test loss 1.737229, test error 53.42
# Training model with  26 hidden variables
# Epoch     0, train loss 2.171444, train error 79.85,  test loss 2.142071, test error 78.93
# Epoch   100, train loss 1.219356, train error 41.00,  test loss 1.349934, test error 50.35
# Epoch   200, train loss 1.058712, train error 34.62,  test loss 1.447516, test error 51.42
# Epoch   300, train loss 0.979245, train error 32.97,  test loss 1.582215, test error 52.67
# Epoch   400, train loss 0.941348, train error 31.90,  test loss 1.683159, test error 52.53
# Epoch   500, train loss 0.919785, train error 31.55,  test loss 1.779742, test error 54.20
# Epoch   600, train loss 0.882076, train error 29.75,  test loss 1.842973, test error 55.38
# Epoch   700, train loss 0.868634, train error 29.20,  test loss 1.883784, test error 54.97
# Epoch   800, train loss 0.845216, train error 28.62,  test loss 1.950224, test error 55.65
# Epoch   900, train loss 0.870861, train error 30.50,  test loss 2.001102, test error 55.67
# Training model with  30 hidden variables
# Epoch     0, train loss 2.178214, train error 80.32,  test loss 2.149045, test error 79.50
# Epoch   100, train loss 1.104969, train error 35.18,  test loss 1.361398, test error 48.95
# Epoch   200, train loss 0.919843, train error 30.95,  test loss 1.536773, test error 51.62
# Epoch   300, train loss 0.826052, train error 27.45,  test loss 1.707759, test error 51.28
# Epoch   400, train loss 0.782829, train error 26.70,  test loss 1.892026, test error 52.62
# Epoch   500, train loss 0.754832, train error 25.93,  test loss 2.087941, test error 54.40
# Epoch   600, train loss 0.722052, train error 23.80,  test loss 2.224203, test error 54.40
# Epoch   700, train loss 0.704969, train error 23.35,  test loss 2.311093, test error 54.62
# Epoch   800, train loss 0.682186, train error 23.40,  test loss 2.412802, test error 54.85
# Epoch   900, train loss 0.673417, train error 22.55,  test loss 2.494068, test error 55.42
# Training model with  35 hidden variables
# Epoch     0, train loss 2.081912, train error 77.35,  test loss 2.022184, test error 77.85
# Epoch   100, train loss 0.989101, train error 31.38,  test loss 1.366489, test error 49.28
# Epoch   200, train loss 0.775355, train error 25.28,  test loss 1.685792, test error 51.15
# Epoch   300, train loss 0.641767, train error 20.47,  test loss 2.035920, test error 51.80
# Epoch   400, train loss 0.560678, train error 18.60,  test loss 2.453983, test error 54.30
# Epoch   500, train loss 0.544099, train error 18.32,  test loss 2.777181, test error 53.80
# Epoch   600, train loss 0.484282, train error 16.10,  test loss 3.149434, test error 54.45
# Epoch   700, train loss 0.453005, train error 14.88,  test loss 3.619589, test error 55.92
# Epoch   800, train loss 0.441477, train error 14.47,  test loss 4.000885, test error 55.62
# Epoch   900, train loss 0.382188, train error 12.57,  test loss 4.394534, test error 56.62
# Training model with  40 hidden variables
# Epoch     0, train loss 2.075072, train error 76.80,  test loss 2.032840, test error 75.45
# Epoch   100, train loss 0.858041, train error 27.05,  test loss 1.370957, test error 48.20
# Epoch   200, train loss 0.590288, train error 18.65,  test loss 1.868486, test error 49.67
# Epoch   300, train loss 0.466903, train error 15.55,  test loss 2.625303, test error 54.33
# Epoch   400, train loss 0.380898, train error 13.55,  test loss 3.414083, test error 54.12
# Epoch   500, train loss 0.316845, train error 10.88,  test loss 4.152970, test error 55.42
# Epoch   600, train loss 0.303808, train error 10.70,  test loss 4.829869, test error 54.40
# Epoch   700, train loss 0.273675, train error 10.22,  test loss 5.457542, test error 55.08
# Epoch   800, train loss 0.300421, train error 10.12,  test loss 6.268013, test error 56.38
# Epoch   900, train loss 0.314096, train error 10.78,  test loss 6.770446, test error 56.35
# Training model with  45 hidden variables
# Epoch     0, train loss 2.091534, train error 77.38,  test loss 2.042614, test error 78.32
# Epoch   100, train loss 0.774970, train error 24.55,  test loss 1.516244, test error 49.78
# Epoch   200, train loss 0.456549, train error 15.18,  test loss 2.229698, test error 52.67
# Epoch   300, train loss 0.321578, train error 10.40,  test loss 3.232319, test error 53.90
# Epoch   400, train loss 0.196760, train error 6.65,  test loss 4.426123, test error 54.42
# Epoch   500, train loss 0.136921, train error 4.57,  test loss 5.609288, test error 54.28
# Epoch   600, train loss 0.180005, train error 6.47,  test loss 6.866666, test error 55.60
# Epoch   700, train loss 0.093315, train error 3.12,  test loss 7.819901, test error 55.88
# Epoch   800, train loss 0.006918, train error 0.00,  test loss 8.580685, test error 55.62
# Epoch   900, train loss 0.004940, train error 0.00,  test loss 9.060785, test error 55.83
# Training model with  50 hidden variables
# Epoch     0, train loss 2.049624, train error 75.43,  test loss 2.008176, test error 75.80
# Epoch   100, train loss 0.704228, train error 23.75,  test loss 1.567428, test error 49.72
# Epoch   200, train loss 0.327026, train error 8.90,  test loss 2.572296, test error 51.53
# Epoch   300, train loss 0.124356, train error 2.25,  test loss 4.017170, test error 52.88
# Epoch   400, train loss 0.030422, train error 0.03,  test loss 5.585338, test error 54.00
# Epoch   500, train loss 0.011698, train error 0.00,  test loss 6.523780, test error 53.95
# Epoch   600, train loss 0.007392, train error 0.00,  test loss 7.117795, test error 54.42
# Epoch   700, train loss 0.005392, train error 0.00,  test loss 7.554912, test error 54.33
# Epoch   800, train loss 0.004221, train error 0.00,  test loss 7.900309, test error 54.22
# Epoch   900, train loss 0.003423, train error 0.00,  test loss 8.182601, test error 54.33
# Training model with  55 hidden variables
# Epoch     0, train loss 2.068192, train error 76.82,  test loss 2.000743, test error 77.35
# Epoch   100, train loss 0.596172, train error 18.20,  test loss 1.627477, test error 50.03
# Epoch   200, train loss 0.218182, train error 5.95,  test loss 2.987653, test error 53.72
# Epoch   300, train loss 0.032316, train error 0.00,  test loss 4.613235, test error 54.35
# Epoch   400, train loss 0.012301, train error 0.00,  test loss 5.527432, test error 54.58
# Epoch   500, train loss 0.007272, train error 0.00,  test loss 6.071156, test error 54.88
# Epoch   600, train loss 0.005035, train error 0.00,  test loss 6.465251, test error 54.62
# Epoch   700, train loss 0.003799, train error 0.00,  test loss 6.762996, test error 54.53
# Epoch   800, train loss 0.003030, train error 0.00,  test loss 7.018495, test error 54.53
# Epoch   900, train loss 0.002516, train error 0.00,  test loss 7.226541, test error 54.35
# Training model with  60 hidden variables
# Epoch     0, train loss 2.037532, train error 75.85,  test loss 1.991461, test error 76.20
# Epoch   100, train loss 0.545275, train error 15.82,  test loss 1.751001, test error 51.97
# Epoch   200, train loss 0.121290, train error 1.47,  test loss 3.403079, test error 54.12
# Epoch   300, train loss 0.021588, train error 0.00,  test loss 4.788668, test error 54.25
# Epoch   400, train loss 0.009882, train error 0.00,  test loss 5.537949, test error 54.50
# Epoch   500, train loss 0.006226, train error 0.00,  test loss 6.020249, test error 54.67
# Epoch   600, train loss 0.004424, train error 0.00,  test loss 6.376122, test error 54.72
# Epoch   700, train loss 0.003400, train error 0.00,  test loss 6.657026, test error 54.67
# Epoch   800, train loss 0.002707, train error 0.00,  test loss 6.887357, test error 54.78
# Epoch   900, train loss 0.002244, train error 0.00,  test loss 7.079521, test error 54.83
# Training model with  70 hidden variables
# Epoch     0, train loss 2.006726, train error 74.75,  test loss 1.921420, test error 74.28
# Epoch   100, train loss 0.387309, train error 9.65,  test loss 1.905398, test error 52.65
# Epoch   200, train loss 0.035432, train error 0.00,  test loss 3.538331, test error 53.28
# Epoch   300, train loss 0.011688, train error 0.00,  test loss 4.365357, test error 53.58
# Epoch   400, train loss 0.006338, train error 0.00,  test loss 4.815430, test error 53.42
# Epoch   500, train loss 0.004259, train error 0.00,  test loss 5.119827, test error 53.50
# Epoch   600, train loss 0.003138, train error 0.00,  test loss 5.361279, test error 53.47
# Epoch   700, train loss 0.002456, train error 0.00,  test loss 5.551200, test error 53.55
# Epoch   800, train loss 0.002004, train error 0.00,  test loss 5.710543, test error 53.40
# Epoch   900, train loss 0.001686, train error 0.00,  test loss 5.847843, test error 53.55
# Training model with  80 hidden variables
# Epoch     0, train loss 2.032482, train error 75.70,  test loss 1.961227, test error 74.90

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 8
#       5 num_training_examples = len(data['y'])
#       7 # Find the index where total_weights_all is closest to num_training_examples
# ----> 8 closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))
#      10 # Get the corresponding value of hidden variables
#      11 hidden_variable_at_num_training_examples = hidden_variables[closest_index]
#
# NameError: name 'total_weights_all' is not defined
