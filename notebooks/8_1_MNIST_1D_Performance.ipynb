# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository|
# %pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /private/var/folders/9q/jm09lzq10jq70lvcx2l0ywfm0000gn/T/pip-req-build-3v5z_4dd
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /private/var/folders/9q/jm09lzq10jq70lvcx2l0ywfm0000gn/T/pip-req-build-3v5z_4dd
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (2.31.0)
# Requirement already satisfied: numpy in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (1.24.3)
# Requirement already satisfied: matplotlib in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (3.7.2)
# Requirement already satisfied: scipy in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from mnist1d==0.0.2.post16) (1.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from matplotlib->mnist1d==0.0.2.post16) (5.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from requests->mnist1d==0.0.2.post16) (2023.11.17)
# Requirement already satisfied: zipp>=3.1.0 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib->mnist1d==0.0.2.post16) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/jiaming/anaconda3/envs/pytorch/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TO DO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):

model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),    
    torch.nn.ReLU(),              
    torch.nn.Linear(D_k, D_k),    
    torch.nn.ReLU(),              
    torch.nn.Linear(D_k, D_o)    
)

"""model = torch.nn.Sequential(
    torch.nn.Linear(D_i, D_k),    
    torch.nn.ReLU(),              
    torch.nn.Linear(D_k, D_k),    
    torch.nn.ReLU(),              
    torch.nn.Linear(D_k, D_k),    
    torch.nn.ReLU(),
    torch.nn.Linear(D_k, D_o)    
)
"""

  
def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
    if isinstance(layer_in, torch.nn.Linear):  
        torch.nn.init.kaiming_normal_(layer_in.weight, mode='fan_in', nonlinearity='relu')
        
        if layer_in.bias is not None:
            torch.nn.init.zeros_(layer_in.bias)
    
# Call the function you just defined
model.apply(weights_init)
# Out:
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('int64'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('int64'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_test[epoch]= loss_function(pred_test, y_test).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Epoch     0, train loss 1.589771, train error 62.42,  test loss 1.673970, test error 67.90
# Epoch     1, train loss 1.332217, train error 48.67,  test loss 1.473871, test error 57.10
# Epoch     2, train loss 1.119125, train error 40.12,  test loss 1.306519, test error 51.10
# Epoch     3, train loss 0.983647, train error 35.43,  test loss 1.223536, test error 47.70
# Epoch     4, train loss 0.890995, train error 32.20,  test loss 1.174425, test error 46.40
# Epoch     5, train loss 0.793114, train error 28.85,  test loss 1.174489, test error 44.60
# Epoch     6, train loss 0.690521, train error 23.85,  test loss 1.124638, test error 43.70
# Epoch     7, train loss 0.640556, train error 22.12,  test loss 1.109509, test error 40.30
# Epoch     8, train loss 0.547651, train error 18.07,  test loss 1.086962, test error 40.10
# Epoch     9, train loss 0.512297, train error 17.80,  test loss 1.131710, test error 40.60
# Epoch    10, train loss 0.403880, train error 11.43,  test loss 1.048739, test error 37.10
# Epoch    11, train loss 0.362725, train error 10.20,  test loss 1.035739, test error 37.20
# Epoch    12, train loss 0.341965, train error 9.50,  test loss 1.071805, test error 36.70
# Epoch    13, train loss 0.303550, train error 7.93,  test loss 1.093223, test error 37.80
# Epoch    14, train loss 0.285886, train error 7.38,  test loss 1.102450, test error 37.40
# Epoch    15, train loss 0.251332, train error 5.35,  test loss 1.085225, test error 36.30
# Epoch    16, train loss 0.229818, train error 4.68,  test loss 1.102828, test error 36.50
# Epoch    17, train loss 0.214434, train error 4.38,  test loss 1.143316, test error 36.80
# Epoch    18, train loss 0.200639, train error 4.25,  test loss 1.181120, test error 37.00
# Epoch    19, train loss 0.177189, train error 3.53,  test loss 1.167659, test error 37.30
# Epoch    20, train loss 0.149336, train error 1.45,  test loss 1.150284, test error 37.20
# Epoch    21, train loss 0.139014, train error 1.40,  test loss 1.164540, test error 36.70
# Epoch    22, train loss 0.132397, train error 1.12,  test loss 1.168255, test error 36.20
# Epoch    23, train loss 0.126054, train error 1.05,  test loss 1.183547, test error 35.80
# Epoch    24, train loss 0.119750, train error 0.78,  test loss 1.191636, test error 36.10
# Epoch    25, train loss 0.114407, train error 0.68,  test loss 1.222874, test error 37.70
# Epoch    26, train loss 0.108483, train error 0.62,  test loss 1.210802, test error 36.70
# Epoch    27, train loss 0.102476, train error 0.38,  test loss 1.231207, test error 36.50
# Epoch    28, train loss 0.097131, train error 0.38,  test loss 1.250013, test error 37.00
# Epoch    29, train loss 0.093105, train error 0.25,  test loss 1.263410, test error 36.90
# Epoch    30, train loss 0.089271, train error 0.25,  test loss 1.252852, test error 36.50
# Epoch    31, train loss 0.085403, train error 0.18,  test loss 1.263767, test error 36.40
# Epoch    32, train loss 0.083690, train error 0.15,  test loss 1.264084, test error 36.60
# Epoch    33, train loss 0.081815, train error 0.15,  test loss 1.272630, test error 36.60
# Epoch    34, train loss 0.079588, train error 0.15,  test loss 1.274555, test error 36.40
# Epoch    35, train loss 0.077699, train error 0.15,  test loss 1.282058, test error 36.30
# Epoch    36, train loss 0.076414, train error 0.15,  test loss 1.283020, test error 36.40
# Epoch    37, train loss 0.074351, train error 0.12,  test loss 1.288344, test error 36.40
# Epoch    38, train loss 0.072807, train error 0.15,  test loss 1.294241, test error 36.70
# Epoch    39, train loss 0.071154, train error 0.15,  test loss 1.303023, test error 36.70
# Epoch    40, train loss 0.070140, train error 0.12,  test loss 1.301881, test error 36.60
# Epoch    41, train loss 0.069416, train error 0.12,  test loss 1.307102, test error 36.60
# Epoch    42, train loss 0.068481, train error 0.12,  test loss 1.308679, test error 36.60
# Epoch    43, train loss 0.067686, train error 0.12,  test loss 1.311311, test error 36.40
# Epoch    44, train loss 0.067119, train error 0.12,  test loss 1.313105, test error 36.50
# Epoch    45, train loss 0.066438, train error 0.07,  test loss 1.315466, test error 36.80
# Epoch    46, train loss 0.065666, train error 0.10,  test loss 1.317430, test error 36.40
# Epoch    47, train loss 0.064914, train error 0.12,  test loss 1.321118, test error 36.40
# Epoch    48, train loss 0.064278, train error 0.07,  test loss 1.323518, test error 36.60
# Epoch    49, train loss 0.063641, train error 0.07,  test loss 1.325089, test error 36.60

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?
